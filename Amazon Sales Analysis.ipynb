# %% [markdown]
# <a href="https://colab.research.google.com/github/gunchugh/Amazon-Sales-Analysis/blob/main/Amazon%20Sales%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  Amazon Sales Analysis: Optimizing Sales and Profit through Data-Driven Insights

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing Amazon sales data using Exploratory Data Analysis (EDA) to understand sales patterns, product performance, and the factors that influence business profitability. Since Amazon offers a wide variety of products across different categories, it becomes important to identify which products perform well and which require improvement. The main objective of this project is to convert raw sales data into meaningful insights that can help in making better business decisions.
#
#
#
# The project started by importing the dataset and understanding its structure. The data was examined to identify missing values, duplicate records, and incorrect data types. After cleaning and preparing the dataset, further analysis was performed using Python libraries such as Pandas, NumPy, Matplotlib, and Seaborn. Data preprocessing helped improve the quality of the dataset and ensured that the analysis was accurate and reliable.
#
#
#
# Different exploratory analysis techniques were applied to answer important business questions. Sales, revenue, profit, ratings, product categories, and other important features were analyzed to understand their impact on overall business performance. Visualizations such as bar charts, histograms, scatter plots, box plots, heatmaps, and pair plots were created to represent the data in a simple and understandable manner. These graphs helped identify trends, relationships, and patterns that are difficult to observe from raw data alone.
#
#
#
# During the analysis, it was observed that some products and categories contribute significantly more to sales and profit than others. Similarly, a few products show lower performance and require attention in terms of pricing, marketing, or promotional strategies. Customer ratings also provide useful information about product quality and customer satisfaction. These insights help in understanding customer preferences and identifying opportunities for improving business performance.
#
#
#
# The project also highlights the importance of data-driven decision-making. Instead of relying on assumptions, businesses can use historical sales data to understand market trends, plan inventory, optimize pricing, and improve customer experience. Regular analysis of sales data can also help in identifying seasonal demand and preparing suitable business strategies in advance.
#
#
#
# Overall, this project successfully demonstrates how Exploratory Data Analysis can be used to understand Amazon sales data and generate meaningful business insights. The analysis supports better decision-making by identifying high-performing products, understanding customer behaviour, and recognizing factors affecting profitability. The knowledge gained through this project can help businesses improve sales performance, increase customer satisfaction, and achieve sustainable growth while also strengthening practical skills in data analysis and visualization using Python.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/gunchugh/Amazon-Sales-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Amazon generates a large volume of sales across different product categories. However, not all products contribute equally to sales and profit. This project analyzes Amazon sales data to identify sales trends, high-performing products, and factors affecting profitability. The insights will help improve business performance and support better decision-making.

# %% [markdown]
# **Define Your Business Objective?**

# %% [markdown]
# To analyze Amazon sales data, identify top-performing products and categories, understand the impact of pricing and discounts on sales, and provide insights to improve sales, profit, and overall business performance.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path='/content/amazon.csv'
df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (1465, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Visualizing the missing values
missing=df.isnull().sum()

plt.figure(figsize=(10,5))
plt.bar(missing.index,missing.values)
plt.xticks(rotation=90)
plt.title("Missing Values")
plt.xlabel("Columns")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   This dataset contains Amazon sales and Product Information.
# *   It has both numerical and categorical columns.
#
#
# *   Some columns contains missing values.
# *   It helps identify buying pattern and product trends.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# product_id = unique ID of the product
#
# product_name = name of the product
#
# category = product category
#
# discounted_price = selling price after discount
#
# actual_price = Original price of the product
#
# discount_percentage = Percentage of discount
#
# rating = Average customer rating
#
# rating_count = Total number of customers rating
#
# about_product = Product description
#
# user_id = Unique ID of the customer
#
# user_name = Name of the customer
#
# review_id = Unique review ID
#
# review_title = Title of the review
#
# review_content = Customer review
#
# img_link = Product image link
#
# product_link = Amazon product link

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
  print(col)
  print(df[col].nunique())
  print("-----------------------")
# Out:
# product_id
# 1351
# -----------------------
# product_name
# 1337
# -----------------------
# category
# 211
# -----------------------
# discounted_price
# 550
# -----------------------
# actual_price
# 449
# -----------------------
# discount_percentage
# 92
# -----------------------
# rating
# 28
# -----------------------
# rating_count
# 1143
# -----------------------
# about_product
# 1293
# -----------------------
# user_id
# 1194
# -----------------------
# user_name
# 1194
# -----------------------
# review_id
# 1194
# -----------------------
# review_title
# 1194
# -----------------------
# review_content
# 1212
# -----------------------
# img_link
# 1412
# -----------------------
# product_link
# 1465
# -----------------------

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

#check missing values
df.isnull().sum()

#remove duplicate values
df.drop_duplicates()

#check duplicates again
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#coverting rating to numeric
df['rating']=pd.to_numeric(df['rating'],errors='coerce')

#coverting rating_count to numeric
df['rating_count']=df['rating_count'].astype(str)
df['rating_count']=df['rating_count'].str.replace(',','')
df['rating_count']=pd.to_numeric(df['rating_count'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Checked the dataset for missing values.
#
# 1.   Removed duplicate records from the dataset.
#
#
#
# 1.   Converted rating and rating_count into numeric data types.
#
#
# 2.   Verified the data types after cleaning.
#
#
#
#
# 2.   Prepared the dataset for Exploratory Data Analysis (EDA).
#
# INSIGHTS:
#
#
#
#
# Product ratings and rating counts can now be used for further analysis.
#
#
# The cleaned dataset will provide more accurate insights.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# **Top 10 Product Categories:**

# %%
# Count top 10 product categories
top_category = df["category"].value_counts().head(10)
plt.figure(figsize=(12,7))

# Create bar chart
plt.barh(top_category.index, top_category.values,color=['red','orange','gold','green','cyan','blue','purple','pink','brown','gray'])
plt.title("Top 10 Product Categories",fontsize=18,fontweight="bold",color="darkblue")
plt.xlabel("Category",fontsize=13)
plt.ylabel("Number of Products",fontsize=13)
# Rotate category names
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to compare the number of products in different categories. It helps identify the most popular product categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some categories have more products than others.
# Popular categories have higher chances of generating more sales.
# A few categories have fewer products.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The business can focus on popular categories to improve sales and inventory management. Categories with fewer products can be improved to increase growth.

# %% [markdown]
# Yes. Product categories with a low number of products may contribute less to overall sales. Limited product variety can reduce customer interest and affect business growth. Increasing the product range and improving marketing for these categories can help overcome this issue.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# **Rating Distribution**

# %%
plt.figure(figsize=(10,6))

# Plot histogram
plt.hist(df["rating"],bins=10,color='mediumseagreen',edgecolor="black",alpha=0.8)

plt.title("Rating Distribution",fontsize=18,fontweight="bold",color="darkgreen")

plt.xlabel("Rating", fontsize=13)
plt.ylabel("Count", fontsize=13)

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows how product ratings are distributed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most products have good ratings.
# Very few products have low ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# Highly rated products can be promoted to increase customer trust and sales.
#
# Negative Growth:
#
# Products with low ratings may reduce customer satisfaction and sales.Answer Here.Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
#  **Top 10 Highest Rated Products:**

# %%
# Select top 10 rated products
top_rating = df.sort_values("rating", ascending=False).head(10)

plt.figure(figsize=(12,6))

# Create bar graph
plt.bar(top_rating["product_name"].str[:20],top_rating["rating"],color="mediumorchid",edgecolor="black")

plt.title("Top 10 Highest Rated Products",fontsize=18,fontweight="bold",color="darkmagenta")

plt.xlabel("Product", fontsize=13)
plt.ylabel("Rating", fontsize=13)

plt.xticks(rotation=90, fontsize=9)
plt.yticks(fontsize=11)

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart identifies the highest-rated products.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some products have excellent customer ratings.
# Highly rated products are more likely to attract customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The company can promote these products to increase sales.
#
# Negative Growth:
#
# Low-rated products may lose customer interest.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# **Discount Percentage Distribution**

# %%
plt.figure(figsize=(10,6))

# Plot histogram
plt.hist(df["discount_percentage"],bins=10,color="coral",
         edgecolor="black",linewidth=1.2,alpha=0.8)

plt.title("Discount Percentage Distribution",fontsize=18,fontweight="bold",
          color="darkred")

plt.xlabel("Discount Percentage", fontsize=13)
plt.ylabel("Number of Products", fontsize=13)

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps understand how discounts are distributed across products.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most products have medium discounts.
# Very high discounts are less common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The business can plan better discount strategies to improve sales.
#
# Negative Growth:
#
# Excessive discounts may reduce profit margins.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# **Actual Price vs Discounted Price**

# %%
plt.figure(figsize=(10,6))

# Create scatter plot
plt.scatter(df["actual_price"],df["discounted_price"],color="royalblue",edgecolors="black",
alpha=0.6,s=40)

plt.title("Actual Price vs Discounted Price",fontweight="bold",color="navy")

plt.xlabel("Actual Price", fontsize=13)
plt.ylabel("Discounted Price", fontsize=13)

plt.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart compares the relationship between actual price and discounted price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Products with higher actual prices usually have higher discounted prices.
# Discounts reduce the selling price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# This helps optimize pricing and discount strategies to improve revenue.
#
# Negative Growth:
#
# Very high discounts on expensive products may reduce overall profit.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# **Top 10 most reviewed products**

# %%
top_review = df.sort_values("rating_count", ascending=False).head(10)

plt.figure(figsize=(12,6))
plt.bar(top_review["product_name"].str[:25], top_review["rating_count"],color="royalblue",
        edgecolor="black")
plt.title("Top 10 Most Reviewed Products",fontsize=18, fontweight="bold", color="navy")
plt.xlabel("Product", fontsize=13)
plt.ylabel("Rating Count", fontsize=13)

plt.xticks(rotation=90, fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart identifies the products that received the highest number of customer reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some products have significantly more reviews than others.
#
# Products with more reviews are generally more popular.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The business can promote highly reviewed products to attract more customers.
#
# Negative Growth:
#
# Products with very few reviews may receive less customer trust and lower sales.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# **Top 10 Discounted Products**

# %%
# Select top 10 products with highest discount
top_discount = df.sort_values("discount_percentage",
                              ascending=False).head(10)

plt.figure(figsize=(12,6))

plt.bar(top_discount["product_name"].str[:20],top_discount["discount_percentage"],color="darkorange",edgecolor="black")

plt.title("Top 10 Highest Discount Products",fontsize=18, fontweight="bold", color="darkred")
plt.xlabel("Product", fontsize=13)
plt.ylabel("Discount Percentage", fontsize=13)

plt.xticks(rotation=90, fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart identifies products offering the highest discounts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some products offer significantly higher discounts.
#
# Higher discounts may attract more customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#  The business can use discounts strategically to increase sales.
#
# Negative Growth:
# Very high discounts may reduce overall profit margins.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# **Top 10 products by rating count**

# %%
# Select top 10 products by rating count
top_review = df.sort_values("rating_count", ascending=False).head(10)
plt.figure(figsize=(12,6))

# Lollipop chart
plt.hlines(y=top_review["product_name"].str[:25],xmin=0,xmax=top_review["rating_count"],color="skyblue",linewidth=3)

plt.plot(top_review["rating_count"],top_review["product_name"].str[:25],
         "o",color="darkblue",markersize=8)

plt.title("Top 10 Products by Rating Count",fontsize=18,fontweight="bold",color="navy")

plt.xlabel("Rating Count")
plt.ylabel("Product")
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart identifies the products with the highest number of customer ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Popular products receive a large number of ratings.
#
# Highly reviewed products generally attract more buyers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#  These products can be highlighted in promotions to increase customer trust and sales.
#
# Negative Growth:
#  Products with fewer ratings may receive less visibility, leading to lower sales.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# **Discount vs Rating**

# %%
plt.figure(figsize=(8,5))

# Create scatter plot
plt.scatter(df["discount_percentage"], df["rating"])
plt.title("Discount vs Rating")
plt.xlabel("Discount Percentage")
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps understand whether discounts affect customer ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no strong relationship between discounts and ratings.
# Highly discounted products can still have different ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# Discounts alone do not guarantee customer satisfaction.
#
# Negative Growth:
#
# Offering high discounts without improving product quality may reduce profits.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# **Rating Count distribution**

# %%
df["rating_count"] = df["rating_count"].astype(str).str.replace(",", "")
df["rating_count"] = pd.to_numeric(df["rating_count"], errors="coerce")

# %%
plt.figure(figsize=(10,6))

# Histogram
plt.hist(df["rating_count"],bins=12,color="mediumseagreen",
         edgecolor="black",alpha=0.8)

plt.title("Rating Count Distribution",fontsize=18,fontweight="bold",color="darkgreen")

plt.xlabel("Rating Count")
plt.ylabel("Number of Products")

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows how customer reviews are distributed among products.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most products have a moderate number of reviews.
#
# Only a few products receive a very high number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# Products with more reviews can be highlighted to build customer confidence.
#
# Negative Growth:
#
# Products with very few reviews may receive less visibility and lower sales.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# **Average Rating by Category**

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# %%
# Calculate average rating for each category
avg_rating = df.groupby("category")["rating"].mean().sort_values(ascending=False).head(8)

plt.figure(figsize=(8,8))
plt.pie(avg_rating.values,
        labels=avg_rating.index.str[:15],autopct='%1.1f%%',startangle=90,
        colors=['gold','skyblue','lightgreen','pink','orange','violet','cyan','coral'])

plt.title("Average Rating by Category",
          fontsize=18,
          fontweight="bold",
          color="darkblue")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart compares the average customer rating across product categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some categories have higher average ratings.
#
# Highly rated categories indicate better customer satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The business can improve low-rated categories and promote highly rated ones.
#
# Negative Growth:
#
# Categories with lower ratings may experience reduced customer trust and lower sales.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# **Average discount by category**

# %%
# Remove % sign
df["discount_percentage"] = df["discount_percentage"].str.replace("%","")

# Convert to numeric
df["discount_percentage"] = pd.to_numeric(df["discount_percentage"])

# %%
 #Calculate average discount by category
avg_discount = df.groupby("category")["discount_percentage"].mean().sort_values().tail(8)

plt.figure(figsize=(10,6))

plt.hlines(y=avg_discount.index.str[:18],xmin=0,xmax=avg_discount.values,color='gray')

plt.scatter(avg_discount.values,avg_discount.index.str[:18],s=180,
            color=['red','orange','gold','green','cyan','blue','purple','pink'])

plt.title("Average Discount by Category",fontsize=18,fontweight="bold")

plt.xlabel("Average Discount (%)")
plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows which categories offer the highest average discounts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some categories provide higher discounts than others.
#
# Discount strategies differ across categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The business can optimize discounts to increase sales while maintaining profit.
#
# Negative Growth:
#
# Offering very high discounts continuously can reduce profit margins.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# **Top 10 Products by Actual Price**

# %%
df["actual_price"] = df["actual_price"].replace('[₹,]', '', regex=True)
df["actual_price"] = pd.to_numeric(df["actual_price"], errors="coerce")

# %%
# Select top 10 expensive products
top_price = df.sort_values("actual_price",ascending=False).head(10)
plt.figure(figsize=(12,6))

plt.barh(top_price["product_name"].str[:25],top_price["actual_price"],
color=['red','orange','gold','green','cyan','blue','purple','pink','brown','gray'],
         edgecolor="black")

plt.title("Top 10 Products by Actual Price",fontsize=18,fontweight="bold",color="darkgreen")

plt.xlabel("Actual Price")
plt.ylabel("Product")

plt.grid(axis='x', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart identifies the most expensive products.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Premium products have much higher prices.
# High-priced products belong to specific categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact:
#
# The business can target premium customers and improve pricing strategies.
#
# Negative growth:
#
# Very expensive products may attract fewer customers because they are less affordable. This can result in lower sales and negatively affect overall business growth.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# **Correlation Heatmap**

# %%
# Select numeric columns
num = df.select_dtypes(include="number")

# Find correlation
corr = num.corr()

plt.figure(figsize=(8,6))

# Draw heatmap
plt.imshow(corr, cmap="Blues")
plt.title("Correlation Heatmap")
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps understand the relationship between numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some variables have positive correlation.
#
# Some variables have weak correlation.

# %% [markdown]
# #### Chart - 15 - **Pair Plot**

# %%
# Pair Plot visualization code

# %%
import seaborn as sns

# %%
# Select numeric columns only
num = df.select_dtypes(include="number")

# Create pair plot
sns.pairplot(num)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps compare relationships between multiple numerical variables at the same time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows patterns, trends, and possible relationships among variables.
#
# It helps identify clusters and outliers.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis, the client should focus on promoting high-performing products and maintaining adequate stock for them to avoid shortages. Low-performing products should be reviewed for pricing, marketing, or discounts to improve their sales. Customer ratings and reviews should be analyzed regularly to understand customer preferences and improve product quality. Seasonal sales trends should be used to plan inventory and promotional campaigns in advance. By making data-driven decisions, the client can increase sales, improve customer satisfaction, and maximize overall profit.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis of Amazon sales data provided valuable insights into product performance, customer preferences, and sales trends. The analysis showed that understanding customer behavior and identifying top-performing products can help improve business decisions. Data visualization made it easier to discover meaningful patterns and relationships within the dataset. Overall, this project demonstrates how data analysis can support effective business strategies, improve operational efficiency, and contribute to increased sales and profitability.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %%
8882582016
# Out:
# 8882582016
